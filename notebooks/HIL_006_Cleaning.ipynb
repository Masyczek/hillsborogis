# %% [markdown]
# ## HIL-006 Data Inspection and Cleaning
#
# This notebook documents a conservative cleaning workflow for the HIL-006 Metro buildings snapshot. The raw ArcGIS response is preserved unchanged; derived cleaned attributes, geometry, and quality flags are exported separately.
#
# - Source: City of Hillsboro GIS
# - Dataset: Metro buildings
# - Snapshot: `2026-08-26`
# - Geometry: Polygon
# - Coordinate system: Web Mercator Auxiliary Sphere (`WKID 102100`, latest `WKID 3857`)

# %%
from pathlib import Path
import json

import numpy as np
import pandas as pd
from shapely.geometry import Polygon

PROJECT_ROOT = Path.cwd().parent
DATA_VERSION = "2026-08-26"
DATA_ROOT = PROJECT_ROOT / DATA_VERSION
RAW_DIR = DATA_ROOT / "raw"
PROCESSED_DIR = DATA_ROOT / "processed"
RAW_FILE = RAW_DIR / "HIL-006.json"
PROCESSED_FILE = PROCESSED_DIR / "HIL-006_cleaned.json"
MANIFEST_FILE = PROCESSED_DIR / "HIL-006_cleaning_manifest.json"

with open(RAW_FILE, "r", encoding="utf-8") as file:
    raw_data = json.load(file)

df = pd.DataFrame([feature["attributes"] for feature in raw_data["features"]])
print(f"Loaded {RAW_FILE.name}: {len(df):,} rows, {len(df.columns):,} source fields")
print(f"Geometry type: {raw_data.get('geometryType')}")
# Out:
# Loaded HIL-006.json: 138,063 rows, 50 source fields
# Geometry type: esriGeometryPolygon

# %% [markdown]
# ## Raw Structure and Missingness
#
# The initial audit checks field types, missingness, identifier uniqueness, sentinel year values, and the source geometry structure before transformation.

# %%
schema_df = pd.DataFrame(raw_data["fields"])[["name", "alias", "type"]]
missing = df.isna().sum().to_frame("missing_count")
missing["missing_percent"] = (missing["missing_count"] / len(df) * 100).round(1)
identifier_fields = [field for field in ["OBJECTID", "BLDG_ID", "STATE_ID", "WSUNIQUEID", "GlobalID"] if field in df]
identifier_audit = pd.DataFrame({
    "field": identifier_fields,
    "unique_values": [df[field].nunique() for field in identifier_fields],
    "missing_values": [df[field].isna().sum() for field in identifier_fields],
    "duplicate_values": [df[field].duplicated().sum() for field in identifier_fields],
})

print("Field types:")
display(schema_df)
print("Missingness:")
display(missing.sort_values("missing_count", ascending=False))
print("Identifier audit:")
display(identifier_audit)
print("YEAR_BUILT = 0:", int((df["YEAR_BUILT"] == 0).sum()))
print("YEAR_BUILT outside 1800-2026:", int(((df["YEAR_BUILT"] < 1800) | (df["YEAR_BUILT"] > 2026)).sum()))
# Out:
# Field types:
#                     name                 alias                       type
# 0               OBJECTID              OBJECTID           esriFieldTypeOID
# 1                BLDG_ID               BLDG_ID        esriFieldTypeString
# 2               STATE_ID              STATE_ID        esriFieldTypeString
# 3              BLDG_NUMB             BLDG_NUMB  esriFieldTypeSmallInteger
# 4              BLDG_NAME             BLDG_NAME        esriFieldTypeString
# 5              BLDG_ADDR             BLDG_ADDR        esriFieldTypeString
# 6              BLDG_TYPE             BLDG_TYPE        esriFieldTypeString
# 7               BLDG_USE              BLDG_USE        esriFieldTypeString
# 8              BLDG_SQFT             BLDG_SQFT       esriFieldTypeInteger
# 9               SQFT_SRC              SQFT_SRC        esriFieldTypeString
# 10             SQFT_CONF             SQFT_CONF        esriFieldTypeString
# 11             NUM_STORY             NUM_STORY  esriFieldTypeSmallInteger
# 12             NUM_UNITS             NUM_UNITS  esriFieldTypeSmallInteger
# 13            YEAR_BUILT            YEAR_BUILT  esriFieldTypeSmallInteger
# 14               ECOROOF               ECOROOF        esriFieldTypeString
# 15             LEED_RATE             LEED_RATE        esriFieldTypeString
# 16                SOURCE                SOURCE        esriFieldTypeString
# 17            SOURCE_REF            SOURCE_REF        esriFieldTypeString
# 18            AVG_HEIGHT            AVG_HEIGHT        esriFieldTypeDouble
# 19            MAX_HEIGHT            MAX_HEIGHT        esriFieldTypeDouble
# 20            MIN_HEIGHT            MIN_HEIGHT        esriFieldTypeDouble
# 21            HEIGHT_SRC            HEIGHT_SRC        esriFieldTypeString
# 22            HEIGHTCONF            HEIGHTCONF        esriFieldTypeString
# 23             SURF_ELEV             SURF_ELEV        esriFieldTypeDouble
# 24              SURF_OFF              SURF_OFF        esriFieldTypeDouble
# 25              SURF_ADJ              SURF_ADJ        esriFieldTypeDouble
# 26              SURF_SRC              SURF_SRC        esriFieldTypeString
# 27             ROOF_ELEV             ROOF_ELEV        esriFieldTypeDouble
# 28             ROOF_TYPE             ROOF_TYPE        esriFieldTypeString
# 29                ORIENT                ORIENT        esriFieldTypeDouble
# 30                VOLUME                VOLUME       esriFieldTypeInteger
# 31            MULTI_POLY            MULTI_POLY        esriFieldTypeString
# 32              MODIFIER              MODIFIER        esriFieldTypeString
# 33              MOD_NAME              MOD_NAME        esriFieldTypeString
# 34              MOD_DATE              MOD_DATE          esriFieldTypeDate
# 35            CREATED_BY            CREATED_BY        esriFieldTypeString
# 36            CREATEDATE            CREATEDATE          esriFieldTypeDate
# 37            FIELD_DATE            FIELD_DATE          esriFieldTypeDate
# 38                REVIEW                REVIEW        esriFieldTypeString
# 39                 NOTES                 NOTES        esriFieldTypeString
# 40               SUBAREA               SUBAREA        esriFieldTypeString
# 41               LAT_CTR               LAT_CTR        esriFieldTypeDouble
# 42              LONG_CTR              LONG_CTR        esriFieldTypeDouble
# 43             USGS_QUAD             USGS_QUAD        esriFieldTypeString
# 44            WSUNIQUEID            WSUNIQUEID        esriFieldTypeString
# 45            BPS_BLDGID            BPS_BLDGID       esriFieldTypeInteger
# 46                LENGTH                LENGTH        esriFieldTypeDouble
# 47        SHAPE.STArea()        SHAPE.STArea()        esriFieldTypeDouble
# 48      SHAPE.STLength()      SHAPE.STLength()        esriFieldTypeDouble
# 49  METRO.buildings.AREA  METRO.buildings.AREA        esriFieldTypeDouble
# Missingness:
#                       missing_count  missing_percent
# FIELD_DATE                   137840             99.8
# MOD_DATE                     120869             87.5
# CREATEDATE                    34933             25.3
# STATE_ID                          0              0.0
# BLDG_NAME                         0              0.0
# BLDG_ADDR                         0              0.0
# BLDG_TYPE                         0              0.0
# BLDG_NUMB                         0              0.0
# BLDG_SQFT                         0              0.0
# SQFT_SRC                          0              0.0
# SQFT_CONF                         0              0.0
# NUM_STORY                         0              0.0
# NUM_UNITS                         0              0.0
# YEAR_BUILT                        0              0.0
# ECOROOF                           0              0.0
# BLDG_USE                          0              0.0
# OBJECTID                          0              0.0
# BLDG_ID                           0              0.0
# SOURCE_REF                        0              0.0
# SOURCE                            0              0.0
# LEED_RATE                         0              0.0
# AVG_HEIGHT                        0              0.0
# HEIGHTCONF                        0              0.0
# MAX_HEIGHT                        0              0.0
# MIN_HEIGHT                        0              0.0
# HEIGHT_SRC                        0              0.0
# SURF_SRC                          0              0.0
# ROOF_ELEV                         0              0.0
# ROOF_TYPE                         0              0.0
# ORIENT                            0              0.0
# VOLUME                            0              0.0
# SURF_ELEV                         0              0.0
# SURF_OFF                          0              0.0
# SURF_ADJ                          0              0.0
# MOD_NAME                          0              0.0
# MODIFIER                          0              0.0
# MULTI_POLY                        0              0.0
# CREATED_BY                        0              0.0
# REVIEW                            0              0.0
# NOTES                             0              0.0
# SUBAREA                           0              0.0
# LAT_CTR                           0              0.0
# LONG_CTR                          0              0.0
# USGS_QUAD                         0              0.0
# WSUNIQUEID                        0              0.0
# BPS_BLDGID                        0              0.0
# LENGTH                            0              0.0
# SHAPE.STArea()                    0              0.0
# SHAPE.STLength()                  0              0.0
# METRO.buildings.AREA              0              0.0
# Identifier audit:
#         field  unique_values  missing_values  duplicate_values
# 0    OBJECTID         138063               0                 0
# 1     BLDG_ID         136560               0              1503
# 2    STATE_ID          97168               0             40895
# 3  WSUNIQUEID         111580               0             26483
# YEAR_BUILT = 0: 36397
# YEAR_BUILT outside 1800-2026: 36401

# %% [markdown]
# ## Geometry and Derived Clean View
#
# Polygon rings are converted for validation only. Invalid polygons are repaired in the derived view with `make_valid`; source rings and source attributes remain unchanged.

# %%
def arcgis_polygon_to_shapely(geometry):
    rings = geometry.get("rings", []) if geometry else []
    if not rings:
        return None
    try:
        return Polygon(rings[0], holes=rings[1:])
    except (TypeError, ValueError):
        return None

geometry_records = []
for feature in raw_data["features"]:
    geometry = feature.get("geometry") or {}
    rings = geometry.get("rings", [])
    polygon = arcgis_polygon_to_shapely(geometry)
    geometry_records.append({
        "geometry": polygon,
        "ring_count": len(rings),
        "vertex_count": sum(len(ring) for ring in rings),
    })

geometry_df = pd.DataFrame(geometry_records)
geometry_df["valid_source_geometry"] = geometry_df["geometry"].map(
    lambda geometry: geometry is not None and geometry.is_valid
)
geometry_df["empty_geometry_flag"] = geometry_df["geometry"].isna()
geometry_df["area"] = geometry_df["geometry"].map(
    lambda geometry: geometry.area if geometry is not None else np.nan
)
geometry_df["length"] = geometry_df["geometry"].map(
    lambda geometry: geometry.length if geometry is not None else np.nan
)

print("Geometry records:", len(geometry_df))
print("Invalid geometries:", int((~geometry_df["valid_source_geometry"] & ~geometry_df["empty_geometry_flag"]).sum()))
print("Empty geometries:", int(geometry_df["empty_geometry_flag"].sum()))
print("Multipart or interior-ring records:", int((geometry_df["ring_count"] > 1).sum()))
# Out:
# Geometry records: 138063
# Invalid geometries: 53
# Empty geometries: 0
# Multipart or interior-ring records: 248

# %%
from shapely.validation import make_valid

analysis_df = df.copy()
text_columns = analysis_df.select_dtypes(include=["str"]).columns
for column in text_columns:
    analysis_df[column] = analysis_df[column].map(
        lambda value: None if isinstance(value, str) and not value.strip() else value
    )

for column in ["MOD_DATE", "CREATEDATE", "FIELD_DATE"]:
    analysis_df[column] = pd.to_datetime(
        analysis_df[column], unit="ms", utc=True, errors="coerce"
    ).dt.strftime("%Y-%m-%dT%H:%M:%SZ")
    analysis_df[column] = analysis_df[column].where(analysis_df[column].notna(), None)

analysis_df["YEAR_BUILT_ZERO_QA_FLAG"] = df["YEAR_BUILT"] == 0
analysis_df["YEAR_BUILT_RANGE_QA_FLAG"] = (df["YEAR_BUILT"] < 1800) | (df["YEAR_BUILT"] > 2026)
analysis_df["GEOMETRY_REPAIRED"] = ~geometry_df["valid_source_geometry"] & ~geometry_df["empty_geometry_flag"]
analysis_df["GEOMETRY_EMPTY_QA_FLAG"] = geometry_df["empty_geometry_flag"]
analysis_df["GEOMETRY_QA_FLAG"] = analysis_df["GEOMETRY_REPAIRED"]
analysis_df["OBJECTID_DUPLICATE_QA_FLAG"] = analysis_df["OBJECTID"].duplicated(keep=False)
analysis_df["BLDG_ID_DUPLICATE_QA_FLAG"] = analysis_df["BLDG_ID"].duplicated(keep=False)
if "GlobalID" in analysis_df.columns:
    analysis_df["GLOBALID_DUPLICATE_QA_FLAG"] = analysis_df["GlobalID"].duplicated(keep=False)
analysis_df["NEGATIVE_AREA_QA_FLAG"] = df["SHAPE.STArea()"] < 0

completely_missing_fields = [column for column in df.columns if df[column].isna().all()]
analysis_df_compact = analysis_df.drop(columns=completely_missing_fields)
analysis_geometry_by_id = {}
for index, row in geometry_df.iterrows():
    geometry = row["geometry"]
    analysis_geometry_by_id[df.iloc[index]["OBJECTID"]] = (
        make_valid(geometry) if geometry is not None and not geometry.is_valid else geometry
    )

print("Completely missing source fields:", completely_missing_fields)
print("Derived analytical fields:", len(analysis_df_compact.columns))
print("QA flag totals:")
display(analysis_df.filter(like="_QA_FLAG").sum().to_frame("flagged_records"))
# Out:
# Completely missing source fields: []
# Derived analytical fields: 58
# QA flag totals:
#                             flagged_records
# YEAR_BUILT_ZERO_QA_FLAG               36397
# YEAR_BUILT_RANGE_QA_FLAG              36401
# GEOMETRY_EMPTY_QA_FLAG                    0
# GEOMETRY_QA_FLAG                         53
# OBJECTID_DUPLICATE_QA_FLAG                0
# BLDG_ID_DUPLICATE_QA_FLAG              2465
# NEGATIVE_AREA_QA_FLAG                     0

# %% [markdown]
# ## Validation and Export
#
# Rows and source geometries are preserved one-for-one. Invalid polygons are repaired only in the processed derived view; valid source geometries are copied directly to avoid unnecessary coordinate rewriting.

# %%
assert len(raw_data["features"]) == len(analysis_df) == 138063
assert analysis_df["OBJECTID"].is_unique
assert not analysis_df["GEOMETRY_EMPTY_QA_FLAG"].any()
assert all(
    geometry is not None and geometry.is_valid and geometry.area >= 0
    for geometry in analysis_geometry_by_id.values()
)
assert analysis_df_compact.columns.is_unique

print("Cleaning validation passed")
print(f"Rows preserved: {len(analysis_df):,}")
print(f"Compact fields: {len(analysis_df_compact.columns):,}")
print(f"Repaired geometries: {int(analysis_df['GEOMETRY_REPAIRED'].sum())}")
print(f"YEAR_BUILT zero flags: {int(analysis_df['YEAR_BUILT_ZERO_QA_FLAG'].sum())}")
print(f"YEAR_BUILT range flags: {int(analysis_df['YEAR_BUILT_RANGE_QA_FLAG'].sum())}")
# Out:
# Cleaning validation passed
# Rows preserved: 138,063
# Compact fields: 58
# Repaired geometries: 53
# YEAR_BUILT zero flags: 36397
# YEAR_BUILT range flags: 36401

# %%
import math


def json_safe(value):
    if value is None or value is pd.NA:
        return None
    if isinstance(value, np.generic):
        value = value.item()
    if isinstance(value, float) and math.isnan(value):
        return None
    return value


def geometry_to_arcgis_rings(geometry):
    if geometry is None:
        return None
    polygons = []
    if geometry.geom_type == "Polygon":
        polygons = [geometry]
    elif geometry.geom_type == "MultiPolygon":
        polygons = list(geometry.geoms)
    elif geometry.geom_type == "GeometryCollection":
        for item in geometry.geoms:
            if item.geom_type == "Polygon":
                polygons.append(item)
            elif item.geom_type == "MultiPolygon":
                polygons.extend(item.geoms)
    rings = []
    for polygon in polygons:
        rings.append([[json_safe(x), json_safe(y)] for x, y in polygon.exterior.coords])
        rings.extend(
            [[[json_safe(x), json_safe(y)] for x, y in interior.coords]
             for interior in polygon.interiors]
        )
    return {"rings": rings} if rings else None

schema_records = [field.copy() for field in raw_data["fields"]]
source_field_names = {field["name"] for field in schema_records}
for field_name in analysis_df_compact.columns:
    if field_name not in source_field_names:
        schema_records.append({
            "name": field_name,
            "alias": field_name,
            "type": "esriFieldTypeSmallInteger",
        })

processed_features = []
for index, raw_feature in enumerate(raw_data["features"]):
    attributes = {
        field: json_safe(value)
        for field, value in analysis_df_compact.iloc[index].to_dict().items()
    }
    object_id = df.iloc[index]["OBJECTID"]
    geometry = (
        geometry_to_arcgis_rings(analysis_geometry_by_id[object_id])
        if analysis_df.iloc[index]["GEOMETRY_REPAIRED"]
        else raw_feature.get("geometry")
    )
    processed_features.append({"attributes": attributes, "geometry": geometry})

PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
processed_data = {
    "objectIdFieldName": raw_data.get("objectIdFieldName"),
    "globalIdFieldName": raw_data.get("globalIdFieldName"),
    "geometryType": raw_data.get("geometryType"),
    "spatialReference": raw_data.get("spatialReference"),
    "fields": schema_records,
    "features": processed_features,
    "cleaning_summary": {
        "source_file": RAW_FILE.name,
        "data_version": DATA_VERSION,
        "rows": len(processed_features),
        "compact_attribute_fields": len(analysis_df_compact.columns),
        "completely_missing_source_fields": completely_missing_fields,
        "repaired_geometries": int(analysis_df["GEOMETRY_REPAIRED"].sum()),
        "year_built_zero_flags": int(analysis_df["YEAR_BUILT_ZERO_QA_FLAG"].sum()),
        "year_built_range_flags": int(analysis_df["YEAR_BUILT_RANGE_QA_FLAG"].sum()),
    },
}

with open(PROCESSED_FILE, "w", encoding="utf-8") as file:
    json.dump(processed_data, file, indent=2, ensure_ascii=True)

# %%
from datetime import datetime

cleaning_manifest = [
    {
        "field_or_scope": "Blank text values",
        "action": "Represent blank or whitespace-only strings as missing in derived attributes",
        "source_preserved": True,
        "review_flag": "None",
    },
    {
        "field_or_scope": "MOD_DATE, CREATEDATE, FIELD_DATE",
        "action": "Convert ArcGIS epoch milliseconds to ISO-8601 UTC strings",
        "source_preserved": True,
        "review_flag": "None",
    },
    {
        "field_or_scope": "YEAR_BUILT = 0",
        "action": "Preserve zero in source and flag as a potential missing or unknown year",
        "source_preserved": True,
        "review_flag": "YEAR_BUILT_ZERO_QA_FLAG",
    },
    {
        "field_or_scope": "Invalid polygon geometry",
        "action": "Use make_valid in derived geometry view",
        "source_preserved": True,
        "review_flag": "GEOMETRY_QA_FLAG",
    },
    {
        "field_or_scope": "Duplicate identifiers and negative source areas",
        "action": "Retain source records and flag for review",
        "source_preserved": True,
        "review_flag": "Duplicate and NEGATIVE_AREA_QA_FLAG fields",
    },
]

manifest_data = {
    "dataset": "HIL-006",
    "dataset_name": "metro_buildings",
    "data_version": DATA_VERSION,
    "created_utc": datetime.now().astimezone().isoformat(),
    "source_file": str(RAW_FILE),
    "processed_file": str(PROCESSED_FILE),
    "rows": len(processed_features),
    "cleaning_manifest": cleaning_manifest,
}

with open(MANIFEST_FILE, "w", encoding="utf-8") as file:
    json.dump(manifest_data, file, indent=2, ensure_ascii=True)

with open(PROCESSED_FILE, "r", encoding="utf-8") as file:
    reloaded_processed_data = json.load(file)
with open(MANIFEST_FILE, "r", encoding="utf-8") as file:
    reloaded_manifest_data = json.load(file)

assert len(reloaded_processed_data["features"]) == len(raw_data["features"])
assert len(reloaded_manifest_data["cleaning_manifest"]) == len(cleaning_manifest)
assert reloaded_processed_data["features"][0]["attributes"]["OBJECTID"] == int(df.iloc[0]["OBJECTID"])
print(f"Wrote: {PROCESSED_FILE}")
print(f"Wrote: {MANIFEST_FILE}")
print("Reload validation passed")
# Out:
# Wrote: c:\Users\John\Documents\hillsborogis\2026-08-26\processed\HIL-006_cleaned.json
# Wrote: c:\Users\John\Documents\hillsborogis\2026-08-26\processed\HIL-006_cleaning_manifest.json
# Reload validation passed
